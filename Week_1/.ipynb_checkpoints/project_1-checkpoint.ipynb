# %%
# Question 1
print("Welcome to the Simple Interest Calculator")
p = float(input("Enter the principal amount: "))
r = float(input("Enter the rate: "))
t = float(input("Enter the time: "))

a = p * (1 + (r/100) * t)
print(f"The simple interest is: {a:.2f}")

# Question 2
print("Welcome to the Compound Interest Calculator")
p = float(input("Enter the principal amount: "))
r = float(input("Enter the rate: "))
n = float(input("Enter the number of times interest is compounded per year: "))
t = float(input("Enter the time: "))

a = p * (1 + (r/n) ** (t * n))
print(f"The compound interest is: {a:.2f}")

# Question 3
print("Welcome to the Annuity Planner")
pmt = float(input("Enter the periodic payment: "))
r = float(input("Enter the rate: "))
n = float(input("Enter the number of times interest is compounded per year: "))
t = float(input("Enter the time: "))

a = (pmt) * ((1 + (r/n) ** (t*n) - 1) / (r/n))
print(f"The annuity plan is: {a:.2f}")
# Out:
# Welcome to the Simple Interest Calculator
# Enter the principal amount:  2323
# Enter the rate:  23
# Enter the time:  23
# The simple interest is: 14611.67
# Welcome to the Compound Interest Calculator
# Enter the principal amount:  23
# Enter the rate:  23
# Enter the number of times interest is compounded per year:  23
# Enter the time:  23
# The compound interest is: 46.00
# Welcome to the Annuity Planner
# Enter the periodic payment:  23
# Enter the rate:  23
# Enter the number of times interest is compounded per year:  23
# Enter the time:  23
# The annuity plan is: 23.00

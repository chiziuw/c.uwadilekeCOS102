# %% [markdown]
# Question A: Flowchart and Pseudocode for store checkout after purchase.

# %% [markdown]
# ![](CheckoutFlowchart.png)

# %% [markdown]
# Pseudocode for Store Checkout process post-purchase
#
# BEGIN
# INPUT items
# INPUT quantity
# COMPUTE total_cost = items * quantity
# PRINT total_cost
# IF payment IS "Cash"
#     INPUT cash
# ELSE
#     INPUT card
#
# COMPUTE transaction approval
# PRINT receipt
# PRINT "Bag items"
# PRINT "Customer takes receipt and items"

# %% [markdown]
# Question B: Flowchart for typical weekday morning routine

# %% [markdown]
# ![](MorningFlowchart.png)

# %% [markdown]
# Question C: Flowchart to take 2 name & age inputs then swap the ages.

# %% [markdown]
# ![](AgeComputation.png)
